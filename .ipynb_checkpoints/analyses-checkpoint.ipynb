# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.colors import ListedColormap

# %%
biostats = pd.read_csv('output/biostats.csv')
advanced = pd.read_csv('output/advanced.csv')
per_mins = pd.read_csv('output/per_minute.csv')
per_poss = pd.read_csv('output/per_poss.csv')

biostats['player_link']=biostats['player_link'].astype(str)
advanced['player_link']=advanced['player_link'].astype(str)
per_mins['player_link']=per_mins['player_link'].astype(str)
per_poss['player_link']=per_poss['player_link'].astype(str)

df = biostats.set_index('player_link').join(advanced.set_index('player_link'), rsuffix='irrelevant')\
.join(per_mins.set_index('player_link'), rsuffix='irrelevantt')\
.join(per_poss.set_index('player_link'), rsuffix='_irrelevant')

df = df[list(filter(lambda x: 'Unnamed' not in x and 'irrelevant' not in x, df.columns))]

df = df.loc[(df['mp_per_g'] > 20) & (df['g'] > 15)]
df['row'] = [i for i in range(len(df))]
df['pos_simple'] = [a[-1] for a in df['pos']]

df = df.set_index('row')
print(df.columns.values)
df
# Out:
# ['ranker' 'player' 'pos' 'age' 'team_id' 'g' 'gs' 'mp_per_g' 'fg_per_g'
#  'fga_per_g' 'fg_pct' 'fg3_per_g' 'fg3a_per_g' 'fg3_pct' 'fg2_per_g'
#  'fg2a_per_g' 'fg2_pct' 'efg_pct' 'ft_per_g' 'fta_per_g' 'ft_pct'
#  'orb_per_g' 'drb_per_g' 'trb_per_g' 'ast_per_g' 'stl_per_g' 'blk_per_g'
#  'tov_per_g' 'pf_per_g' 'pts_per_g' 'team_id_link' 'height' 'weight' 'bmi'
#  'mp' 'per' 'ts_pct' 'fg3a_per_fga_pct' 'fta_per_fga_pct' 'orb_pct'
#  'drb_pct' 'trb_pct' 'ast_pct' 'stl_pct' 'blk_pct' 'tov_pct' 'usg_pct'
#  'ws-dum' 'ows' 'dws' 'ws' 'ws_per_48' 'bpm-dum' 'obpm' 'dbpm' 'bpm'
#  'vorp' 'fg_per_mp' 'fga_per_mp' 'fg3_per_mp' 'fg3a_per_mp' 'fg2_per_mp'
#  'fg2a_per_mp' 'ft_per_mp' 'fta_per_mp' 'orb_per_mp' 'drb_per_mp'
#  'trb_per_mp' 'ast_per_mp' 'stl_per_mp' 'blk_per_mp' 'tov_per_mp'
#  'pf_per_mp' 'pts_per_mp' 'fg_per_poss' 'fga_per_poss' 'fg3_per_poss'
#  'fg3a_per_poss' 'fg2_per_poss' 'fg2a_per_poss' 'ft_per_poss'
#  'fta_per_poss' 'orb_per_poss' 'drb_per_poss' 'trb_per_poss'
#  'ast_per_poss' 'stl_per_poss' 'blk_per_poss' 'tov_per_poss' 'pf_per_poss'
#  'pts_per_poss' 'off_rtg' 'def_rtg' 'pos_simple']
#      ranker             player pos  age team_id   g  gs  mp_per_g  fg_per_g  \
# row
# 0         1       Steven Adams   C   26     OKC  29  29      27.8       5.0
# 1         2        Bam Adebayo   C   22     MIA  32  32      34.3       5.8
# 2         3  LaMarcus Aldridge   C   34     SAS  29  29      32.9       7.9
# 3         6      Jarrett Allen   C   21     BRK  31  28      26.5       4.7
# 4         8    Al-Farouq Aminu  PF   29     ORL  18   2      21.1       1.4
# ..      ...                ...  ..  ...     ...  ..  ..       ...       ...
# 264     462    Marvin Williams  PF   33     CHO  30   0      20.8       2.6
# 265     468       Delon Wright  SG   27     DAL  30   2      20.5       2.9
# 266     469     Thaddeus Young  PF   31     CHI  32   0      21.8       3.5
# 267     470         Trae Young  PG   21     ATL  31  31      34.9       9.3
# 268     471        Cody Zeller   C   27     CHO  32  20      23.7       4.6
#
#      fga_per_g  ...  trb_per_poss  ast_per_poss  stl_per_poss  blk_per_poss  \
# row             ...
# 0          8.1  ...          17.0           4.8           1.1           2.2
# 1         10.3  ...          14.9           6.5           2.0           1.8
# 2         15.4  ...          10.8           3.5           0.9           2.7
# 3          7.2  ...          18.3           2.3           1.3           2.5
# 4          4.8  ...          11.2           2.7           2.3           1.0
# ..         ...  ...           ...           ...           ...           ...
# 264        5.5  ...           6.6           2.5           1.7           1.1
# 265        5.9  ...           8.4           7.8           3.6           0.7
# 266        8.8  ...           9.8           4.0           2.3           0.5
# 267       20.9  ...           5.7          11.0           1.6           0.1
# 268        8.4  ...          15.8           2.6           1.4           0.9
#
#      tov_per_poss  pf_per_poss  pts_per_poss  off_rtg  def_rtg  pos_simple
# row
# 0             2.7          3.3          20.4    123.0      105           C
# 1             3.9          3.7          22.1    117.0      102           C
# 2             2.1          3.3          28.1    116.0      110           C
# 3             2.1          4.3          21.5    133.0      103           C
# 4             2.2          3.5          10.0     88.0      106           F
# ..            ...          ...           ...      ...      ...         ...
# 264           1.7          4.4          18.0    119.0      113           F
# 265           1.7          2.7          18.5    130.0      105           G
# 266           3.4          4.1          19.2     94.0      105           F
# 267           6.3          2.0          38.0    110.0      116           G
# 268           3.1          5.3          24.4    116.0      111           C
#
# [269 rows x 94 columns]

# %%
pd.set_option('display.max_rows', None)
df.sort_values('usg_pct')[::-1][['player', 'pos', 'usg_pct', 'pts_per_mp', 'ast_per_mp', 'trb_per_mp', 'mp_per_g']].loc[df['pos_simple'] == 'G']
# Out:
#                        player pos  usg_pct  pts_per_mp  ast_per_mp  \
# row
# 136              James Harden  SG     37.7        36.6         7.2
# 107               Luka Dončić  PG     36.9        32.3        10.1
# 267                Trae Young  PG     34.5        29.4         8.6
# 257         Russell Westbrook  PG     32.9        24.6         7.2
# 228          D'Angelo Russell  SG     32.2        26.6         6.9
# 17               Bradley Beal  SG     32.0        27.4         6.6
# 189          Donovan Mitchell  SG     31.5        25.9         4.4
# 105         Spencer Dinwiddie  SG     31.5        26.5         7.3
# 161              LeBron James  PG     31.5        25.9        11.2
# 224              Derrick Rose  PG     30.8        24.7         8.8
# 174               Zach LaVine  SG     30.7        25.4         4.2
# 177            Damian Lillard  PG     28.9        26.4         7.4
# 254              Kemba Walker  PG     28.6        25.0         5.8
# 232           Dennis Schröder  PG     28.3        21.9         4.4
# 26               Devin Booker  SG     28.1        24.9         6.5
# 263              Lou Williams  SG     28.0        22.6         7.4
# 63            Jordan Clarkson  SG     27.8        22.8         3.6
# 64            Jordan Clarkson  SG     27.8        22.8         3.6
# 65            Jordan Clarkson  SG     27.8        22.9         3.8
# 62            Jordan Clarkson  SG     27.8        22.8         3.6
# 92            Jordan Clarkson  SG     27.8        22.9         3.8
# 94            Jordan Clarkson  SG     27.8        22.9         3.8
# 66            Jordan Clarkson  SG     27.8        22.9         3.8
# 91            Jordan Clarkson  SG     27.8        22.8         3.6
# 67            Jordan Clarkson  SG     27.8        22.9         3.8
# 68            Jordan Clarkson  SG     27.8        22.4         1.6
# 69            Jordan Clarkson  SG     27.8        22.4         1.6
# 96            Jordan Clarkson  SG     27.8        22.4         1.6
# 70            Jordan Clarkson  SG     27.8        22.4         1.6
# 93            Jordan Clarkson  SG     27.8        22.9         3.8
# 89            Jordan Clarkson  SG     27.8        22.8         3.6
# 90            Jordan Clarkson  SG     27.8        22.8         3.6
# 97            Jordan Clarkson  SG     27.8        22.4         1.6
# 95            Jordan Clarkson  SG     27.8        22.4         1.6
# 145               Buddy Hield  SG     27.5        21.3         3.2
# 191                 Ja Morant  PG     27.0        21.5         8.0
# 233             Collin Sexton  SG     26.8        21.1         2.8
# 31            Malcolm Brogdon  PG     26.4        21.0         8.7
# 127           Devonte' Graham  PG     25.9        19.8         8.0
# 45            Jordan Clarkson  SG     25.9        22.8         3.6
# 71            Jordan Clarkson  SG     25.9        22.8         3.6
# 72            Jordan Clarkson  SG     25.9        22.8         3.6
# 73            Jordan Clarkson  SG     25.9        22.8         3.6
# 74            Jordan Clarkson  SG     25.9        22.9         3.8
# 75            Jordan Clarkson  SG     25.9        22.9         3.8
# 76            Jordan Clarkson  SG     25.9        22.9         3.8
# 44            Jordan Clarkson  SG     25.9        22.8         3.6
# 78            Jordan Clarkson  SG     25.9        22.4         1.6
# 51            Jordan Clarkson  SG     25.9        22.4         1.6
# 46            Jordan Clarkson  SG     25.9        22.8         3.6
# 47            Jordan Clarkson  SG     25.9        22.9         3.8
# 48            Jordan Clarkson  SG     25.9        22.9         3.8
# 49            Jordan Clarkson  SG     25.9        22.9         3.8
# 79            Jordan Clarkson  SG     25.9        22.4         1.6
# 50            Jordan Clarkson  SG     25.9        22.4         1.6
# 52            Jordan Clarkson  SG     25.9        22.4         1.6
# 148              Jrue Holiday  SG     25.9        20.0         6.6
# 77            Jordan Clarkson  SG     25.9        22.4         1.6
# 183               CJ McCollum  SG     25.8        21.9         3.6
# 86            Jordan Clarkson  SG     25.7        22.4         1.6
# 82            Jordan Clarkson  SG     25.7        22.8         3.6
# 84            Jordan Clarkson  SG     25.7        22.9         3.8
# 87            Jordan Clarkson  SG     25.7        22.4         1.6
# 88            Jordan Clarkson  SG     25.7        22.4         1.6
# 85            Jordan Clarkson  SG     25.7        22.9         3.8
# 81            Jordan Clarkson  SG     25.7        22.8         3.6
# 80            Jordan Clarkson  SG     25.7        22.8         3.6
# 83            Jordan Clarkson  SG     25.7        22.9         3.8
# 56            Jordan Clarkson  SG     25.7        22.9         3.8
# 53            Jordan Clarkson  SG     25.7        22.8         3.6
# 58            Jordan Clarkson  SG     25.7        22.9         3.8
# 54            Jordan Clarkson  SG     25.7        22.8         3.6
# 55            Jordan Clarkson  SG     25.7        22.8         3.6
# 59            Jordan Clarkson  SG     25.7        22.4         1.6
# 57            Jordan Clarkson  SG     25.7        22.9         3.8
# 61            Jordan Clarkson  SG     25.7        22.4         1.6
# 60            Jordan Clarkson  SG     25.7        22.4         1.6
# 124   Shai Gilgeous-Alexander  SG     25.2        20.1         2.9
# 116             Evan Fournier  SG     25.1        22.7         3.8
# 195              Jamal Murray  PG     25.0        19.5         5.2
# 108              Goran Dragić  PG     24.5        20.0         6.3
# 226              Terry Rozier  PG     24.5        18.6         4.6
# 23               Eric Bledsoe  PG     24.0        20.3         7.6
# 198             Kendrick Nunn  SG     23.9        18.9         4.2
# 24          Bogdan Bogdanović  SG     23.8        18.7         4.7
# 245             Isaiah Thomas  PG     23.7        19.6         6.7
# 98                Mike Conley  PG     23.6        16.6         5.7
# 258                Coby White  SG     23.5        17.0         3.4
# 32              Dillon Brooks  SG     23.2        18.5         2.6
# 12                 RJ Barrett  SG     23.1        15.6         3.2
# 180                Kyle Lowry  PG     23.1        19.6         7.0
# 225             Terrence Ross  SG     22.7        18.8         1.3
# 251             Fred VanVleet  PG     22.6        17.9         6.8
# 37                 Alec Burks  SG     22.6        19.2         3.7
# 144               Tyler Herro  SG     22.2        17.4         2.7
# 135              Tim Hardaway  SG     22.0        19.4         2.4
# 206                Chris Paul  PG     21.9        18.8         7.4
# 218           Josh Richardson  SG     21.8        16.9         3.7
# 190                Malik Monk  SG     21.7        16.6         3.8
# 227               Ricky Rubio  PG     21.5        15.9        10.3
# 117            Markelle Fultz  PG     21.4        15.7         5.9
# 194           Dejounte Murray  PG     21.3        15.7         6.3
# 147             Aaron Holiday  PG     21.1        17.0         4.8
# 120            Darius Garland  PG     20.9        14.4         3.7
# 173               Jeremy Lamb  SG     20.4        16.2         2.9
# 175                Damion Lee  SG     20.4        17.4         3.1
# 208              Jordan Poole  SG     20.4        11.7         3.0
# 242               Jeff Teague  PG     20.2        17.4         7.9
# 10                 Lonzo Ball  PG     19.9        13.8         6.6
# 188               Patty Mills  PG     19.7        17.9         3.2
# 101            Jarrett Culver  SG     19.7        12.6         3.1
# 213             Norman Powell  SG     19.6        17.9         2.1
# 168              Luke Kennard  SG     19.6        17.3         4.5
# 236               Ben Simmons  PG     19.6        14.7         8.9
# 237           Anfernee Simons  SG     19.6        15.9         2.2
# 217               J.J. Redick  SG     19.4        19.4         2.5
# 223               Rajon Rondo  PG     18.9        12.9         9.3
# 115               Bryn Forbes  SG     18.8        16.2         2.5
# 207             Elfrid Payton  PG     18.8        11.7         8.9
# 9               D.J. Augustin  PG     17.9        14.0         6.4
# 102                Seth Curry  SG     17.7        16.0         2.9
# 239                 Ish Smith  PG     17.7        14.2         5.9
# 154             Kevin Huerter  SG     17.6        13.4         4.8
# 259             Derrick White  SG     17.4        14.8         4.8
# 35                 Troy Brown  SG     17.1        13.9         3.4
# 238              Marcus Smart  SG     17.1        13.2         5.1
# 171            Furkan Korkmaz  SG     16.8        14.4         1.4
# 106          Donte DiVincenzo  SG     16.6        13.5         3.6
# 28              Avery Bradley  SG     16.4        11.5         1.9
# 231          Tomáš Satoranský  PG     16.3        12.8         6.7
# 27                  Ky Bowman  PG     16.3        12.6         4.7
# 185              Ben McLemore  SG     16.2        15.1         1.5
# 119         Langston Galloway  SG     16.2        15.3         1.9
# 243            Garrett Temple  SG     16.2        13.0         3.1
# 146               George Hill  PG     16.1        17.7         5.0
# 33                Bruce Brown  SG     16.1        11.3         5.0
# 199               Josh Okogie  SG     15.6        11.7         2.1
# 139               Gary Harris  SG     15.2        12.4         2.4
# 265              Delon Wright  SG     15.1        13.8         5.8
# 219             Austin Rivers  SG     15.0        12.6         2.5
# 110                 Kris Dunn  PG     14.9        10.6         4.9
# 39   Kentavious Caldwell-Pope  SG     14.8        13.4         2.6
# 18            DeAndre' Bembry  SG     14.0        10.0         3.5
# 130               Danny Green  SG     13.9        11.8         1.7
# 197           Frank Ntilikina  PG     13.5         9.2         4.7
# 166               Cory Joseph  PG     13.3         8.3         5.3
# 128            Treveon Graham  SG     13.1         9.2         1.5
# 149            Justin Holiday  SG     13.0        10.5         2.1
# 20           Patrick Beverley  PG     12.8        10.0         4.1
# 182           Wesley Matthews  SG     12.7        11.7         2.1
# 234             Landry Shamet  SG     12.7        12.2         2.1
#
#      trb_per_mp  mp_per_g
# row
# 136         5.6      37.7
# 107        10.6      32.0
# 267         4.4      34.9
# 257         8.3      35.3
# 228         3.9      31.4
# 17          4.7      36.6
# 189         4.7      35.1
# 105         3.5      30.7
# 161         7.7      35.0
# 224         3.3      24.4
# 174         5.0      33.3
# 177         4.0      36.8
# 254         4.3      32.4
# 232         4.6      30.2
# 26          3.9      35.7
# 263         3.6      30.3
# 63          3.7      22.9
# 64          3.7      22.9
# 65          3.7      22.9
# 62          3.7      22.9
# 92          3.7      23.0
# 94          3.7      23.0
# 66          3.7      22.9
# 91          3.7      23.0
# 67          3.7      22.9
# 68          3.2      22.9
# 69          3.2      22.9
# 96          3.2      23.0
# 70          3.2      22.9
# 93          3.7      23.0
# 89          3.7      23.0
# 90          3.7      23.0
# 97          3.2      23.0
# 95          3.2      23.0
# 145         5.3      34.2
# 191         4.0      29.3
# 233         3.8      30.6
# 31          5.2      31.4
# 127         4.0      34.7
# 45          3.7      22.9
# 71          3.7      23.0
# 72          3.7      23.0
# 73          3.7      23.0
# 74          3.7      23.0
# 75          3.7      23.0
# 76          3.7      23.0
# 44          3.7      22.9
# 78          3.2      23.0
# 51          3.2      22.9
# 46          3.7      22.9
# 47          3.7      22.9
# 48          3.7      22.9
# 49          3.7      22.9
# 79          3.2      23.0
# 50          3.2      22.9
# 52          3.2      22.9
# 148         4.9      35.7
# 77          3.2      23.0
# 183         4.3      36.6
# 86          3.2      23.0
# 82          3.7      23.0
# 84          3.7      23.0
# 87          3.2      23.0
# 88          3.2      23.0
# 85          3.7      23.0
# 81          3.7      23.0
# 80          3.7      23.0
# 83          3.7      23.0
# 56          3.7      22.9
# 53          3.7      22.9
# 58          3.7      22.9
# 54          3.7      22.9
# 55          3.7      22.9
# 59          3.2      22.9
# 57          3.7      22.9
# 61          3.2      22.9
# 60          3.2      22.9
# 124         5.1      35.3
# 116         3.1      30.8
# 195         4.9      32.0
# 108         4.0      28.9
# 226         4.8      33.4
# 23          6.6      26.7
# 198         3.3      30.6
# 24          3.8      28.4
# 245         2.6      25.5
# 98          4.1      29.4
# 258         5.3      24.0
# 32          4.4      27.7
# 12          6.0      31.7
# 180         4.7      38.1
# 225         4.1      24.9
# 251         3.8      36.5
# 37          5.5      29.1
# 144         5.4      28.8
# 135         3.6      25.5
# 206         5.4      31.7
# 218         4.0      31.7
# 190         5.0      20.3
# 227         5.3      31.8
# 117         3.9      26.2
# 194         8.9      23.6
# 147         3.9      23.2
# 120         2.6      28.2
# 173         5.6      30.3
# 175         7.6      25.3
# 208         3.3      21.7
# 242         3.5      29.4
# 10          6.5      28.3
# 188         2.4      23.0
# 101         5.1      22.0
# 213         4.8      28.9
# 168         3.8      32.9
# 236         7.2      35.2
# 237         4.1      21.9
# 217         3.6      28.4
# 223         6.0      21.5
# 115         3.4      25.8
# 207         5.6      23.9
# 9           3.3      25.8
# 102         3.3      21.8
# 239         4.0      25.3
# 154         4.6      25.3
# 259         4.2      23.6
# 35          8.1      24.2
# 238         3.8      31.4
# 171         3.9      20.8
# 106         7.3      22.3
# 28          3.8      23.9
# 231         4.9      28.2
# 27          4.3      22.8
# 185         3.6      24.1
# 119         3.0      26.4
# 243         4.2      29.1
# 146         5.4      21.5
# 33          6.0      26.6
# 199         6.8      24.3
# 139         3.0      32.9
# 265         6.3      20.5
# 219         3.8      23.5
# 110         5.2      23.6
# 39          3.1      25.4
# 18          6.4      22.5
# 130         5.2      25.4
# 197         3.2      22.5
# 166         3.8      26.8
# 128         5.5      21.1
# 149         5.2      25.1
# 20          7.5      28.9
# 182         3.6      23.9
# 234         2.3      27.2

# %%
labels = {'PG': 1, 'SG': 2, 'SF': 3, 'PF': 4, 'C': 5, 'G': 1.5, 'F': 3.5}

y = 'ast_per_mp'
x = 'trb_per_mp'

l = [labels[i] for i in df['pos']]
colors=['purple', 'blue', 'teal', 'green', 'orange', 'pink', 'red', 'yellow']

for i, pos in enumerate(['PG', 'C']):
    plt.axvline(df.loc[df['pos'] == pos][x].median(), linestyle='--', label=pos + ' (median)', c=colors[i], alpha=.3)
    plt.axhline(df.loc[df['pos'] == pos][y].median(), linestyle='--', c=colors[i], alpha=.3)

plt.scatter(df[x], df[y], c=l, cmap='viridis', alpha=.3)
plt.colorbar().ax.set_ylabel('Position 1-5 (1-PG...5-C)', rotation=270, labelpad=20)

highlight = {'LeBron James', 'Giannis Antetokounmpo', 'Nikola Jokić', 'Luka Dončić', 'Andre Drummond',
            'Domantas Sabonis', 'Russell Westbrook', 'Dejounte Murray', 'Karl-Anthony Towns',
            'Ben Simmons', 'Ricky Rubio', 'Derrick Rose', 'Rajon Rondo'}

for i, txt in enumerate(df['player']):
    if df['player'][i] in highlight:
        plt.annotate(txt[0] + '. ' + txt.split(' ')[-1], (df[x][i], df[y][i]))

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gcf().set_size_inches(15, 9)

plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.gca().set_aspect('equal', adjustable='box')

plt.legend()
plt.title('Rebounds v. Assists by Player Position', fontsize=18)
plt.xlabel('Rebounds per 36 min.', fontsize=12)
plt.ylabel('Assists per 36 min.', fontsize=12)
# Out:
# Text(0, 0.5, 'Assists per 36 min.')

# %%
labels = {'PG': 1, 'SG': 2, 'SF': 3, 'PF': 4, 'C': 5, 'G': 1.5, 'F': 3.5}

y = df['']
x = 'trb_per_mp'

l = [labels[i] for i in df['pos']]
colors=['purple', 'blue', 'teal', 'green', 'orange', 'pink', 'red', 'yellow']

for i, pos in enumerate(['PG', 'C']):
    plt.axvline(df.loc[df['pos'] == pos][x].median(), linestyle='--', label=pos + ' (median)', c=colors[i], alpha=.3)
    plt.axhline(df.loc[df['pos'] == pos][y].median(), linestyle='--', c=colors[i], alpha=.3)
#     plt.plot(np.unique(df.loc[df['pos'] == pos][x]), np.poly1d(np.polyfit(df.loc[df['pos'] == pos][x], df.loc[df['pos'] == pos][y], 1))(np.unique(df.loc[df['pos'] == pos][x])))

plt.scatter(df[x], df[y], c=l, cmap='viridis', alpha=.3)
plt.colorbar().ax.set_ylabel('Position 1-5 (1-PG...5-C)', rotation=270, labelpad=20)

highlight = {'LeBron James', 'Giannis Antetokounmpo', 'Nikola Jokić', 'Luka Dončić', 'Andre Drummond',
            'Domantas Sabonis', 'Russell Westbrook', 'Dejounte Murray', 'Karl-Anthony Towns',
            'Ben Simmons', 'Ricky Rubio', 'Derrick Rose', 'Rajon Rondo'}

for i, txt in enumerate(df['player']):
    if df['player'][i] in highlight:
        plt.annotate(txt[0] + '. ' + txt.split(' ')[-1], (df[x][i], df[y][i]))

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gcf().set_size_inches(15, 9)

plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.gca().set_aspect('equal', adjustable='box')

plt.legend()
plt.title('Rebounds v. Assists by Player Position', fontsize=18)
plt.xlabel('Rebounds per 36 min.', fontsize=12)
plt.ylabel('Assists per 36 min.', fontsize=12)
# Out:
# Text(0, 0.5, 'Assists per 36 min.')

# %%
labels = {'PG': 1, 'SG': 2, 'SF': 3, 'PF': 4, 'C': 5, 'G': 1.5, 'F': 3.5}

def plot(df, x, y, highlight, title, xtitle, ytitle):
    df = df.reset_index()
    l = [labels[i] for i in df['pos']]
    colors=['purple', 'blue', 'teal', 'green', 'orange', 'pink', 'red', 'yellow']

    for i, pos in enumerate(['PG', 'C']):
        plt.axvline(df.loc[df['pos'] == pos][x].median(), linestyle='--', label=pos + ' (median)', c=colors[i], alpha=.3)
        plt.axhline(df.loc[df['pos'] == pos][y].median(), linestyle='--', c=colors[i], alpha=.3)
    #     plt.plot(np.unique(df.loc[df['pos'] == pos][x]), np.poly1d(np.polyfit(df.loc[df['pos'] == pos][x], df.loc[df['pos'] == pos][y], 1))(np.unique(df.loc[df['pos'] == pos][x])))

    plt.scatter(df[x], df[y], c=l, cmap='viridis', alpha=.3)
    plt.colorbar().ax.set_ylabel('Position 1-5 (1-PG...5-C)', rotation=270, labelpad=20)

    for i, txt in enumerate(df['player']):
        if df['player'][i] in highlight:
            plt.annotate(txt[0] + '. ' + txt.split(' ')[-1], (df[x][i], df[y][i]))

    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    plt.gcf().set_size_inches(15, 9)

    plt.ylim(ymin=0)
    plt.xlim(xmin=0)
    plt.gca().set_aspect('equal', adjustable='box')

    plt.legend()
    plt.title(title, fontsize=18)
    plt.xlabel(xtitle, fontsize=12)
    plt.ylabel(ytitle, fontsize=12)

# %%
highlight = {'Draymond Green', 'Jimmy Butler', 'Nikola Jokić'}

pg_ast = df.loc[df['pos'] == 'PG']['ast_per_mp'].median()
c_ast = df.loc[df['pos'] == 'C']['ast_per_mp'].median()
pg_trb = df.loc[df['pos'] == 'PG']['trb_per_mp'].median()
c_trb = df.loc[df['pos'] == 'C']['trb_per_mp'].median()

temp = df.loc[((df['pos_simple'] != 'G') & (df['ast_per_mp'] > pg_ast))]
temp
plot(temp, 'trb_per_mp', 'ast_per_mp', highlight, 'Players with more assists than a median PG that are not Guards',
    'Rebounds per 30 min.', 'Assists per 30 min.')

# %%
highlight = {'Draymond Green', 'Jimmy Butler', 'Nikola Jokić'}

pg_ast = df.loc[df['pos'] == 'PG']['ast_per_mp'].median()
c_ast = df.loc[df['pos'] == 'C']['ast_per_mp'].median()
pg_trb = df.loc[df['pos'] == 'PG']['trb_per_mp'].median()
c_trb = df.loc[df['pos'] == 'C']['trb_per_mp'].median()

temp = df.loc[((df['pos_simple'] != 'C') & (df['trb_per_mp'] > c_trb))]
temp
plot(temp, 'trb_per_mp', 'ast_per_mp', highlight, 'Players with more assists than a median PG that are not Guards',
    'Rebounds per 30 min.', 'Assists per 30 min.')

# %%
temp
# Out:
#      ranker                 player pos  age team_id   g  gs  mp_per_g  \
# row
# 5        11  Giannis Antetokounmpo  PF   25     MIL  31  31      31.1
# 132     172         JaMychal Green  PF   29     LAC  25   0      20.6
# 179     279             Kevin Love  PF   31     CLE  27  27      30.6
#
#      fg_per_g  fga_per_g  ...  trb_per_poss  ast_per_poss  stl_per_poss  \
# row                       ...
# 5        11.4       20.5  ...          19.1           8.4           1.9
# 132       2.4        6.0  ...          14.3           1.4           1.4
# 179       5.4       12.0  ...          16.8           4.6           0.9
#
#      blk_per_poss  tov_per_poss  pf_per_poss  pts_per_poss  off_rtg  def_rtg  \
# row
# 5             1.8           5.4          4.6          45.1    117.0       96
# 132           0.7           1.9          5.5          16.0    109.0      104
# 179           0.6           4.3          2.1          26.5    110.0      111
#
#      pos_simple
# row
# 5             F
# 132           F
# 179           F
#
# [3 rows x 94 columns]
