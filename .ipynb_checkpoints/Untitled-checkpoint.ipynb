# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.colors import ListedColormap

# %%
biostats = pd.read_csv('output/biostats.csv')
advanced = pd.read_csv('output/advanced_with_points_generated.csv')
per_mins = pd.read_csv('output/per_minute.csv')
per_poss = pd.read_csv('output/per_poss.csv')

biostats['player_link']=biostats['player_link'].astype(str)
advanced['player_link']=advanced['player_link'].astype(str)
per_mins['player_link']=per_mins['player_link'].astype(str)
per_poss['player_link']=per_poss['player_link'].astype(str)

df = biostats.set_index('player_link').join(advanced.set_index('player_link'), rsuffix='irrelevant')\
.join(per_mins.set_index('player_link'), rsuffix='irrelevantt')\
.join(per_poss.set_index('player_link'), rsuffix='_irrelevant')

df = df[list(filter(lambda x: 'Unnamed' not in x and 'irrelevant' not in x, df.columns))]

df = df.loc[(df['mp_per_g'] > 20) & (df['g'] > 20)]
df['row'] = [i for i in range(len(df))]
df['pos_simple'] = [a[-1] for a in df['pos']]

df = df.set_index('row')
print(df.columns.values)
df
# Out:
# ['ranker' 'player' 'pos' 'age' 'team_id' 'g' 'gs' 'mp_per_g' 'fg_per_g'
#  'fga_per_g' 'fg_pct' 'fg3_per_g' 'fg3a_per_g' 'fg3_pct' 'fg2_per_g'
#  'fg2a_per_g' 'fg2_pct' 'efg_pct' 'ft_per_g' 'fta_per_g' 'ft_pct'
#  'orb_per_g' 'drb_per_g' 'trb_per_g' 'ast_per_g' 'stl_per_g' 'blk_per_g'
#  'tov_per_g' 'pf_per_g' 'pts_per_g' 'team_id_link' 'height' 'weight' 'bmi'
#  'mp' 'per' 'ts_pct' 'fg3a_per_fga_pct' 'fta_per_fga_pct' 'orb_pct'
#  'drb_pct' 'trb_pct' 'ast_pct' 'stl_pct' 'blk_pct' 'tov_pct' 'usg_pct'
#  'ws-dum' 'ows' 'dws' 'ws' 'ws_per_48' 'bpm-dum' 'obpm' 'dbpm' 'bpm'
#  'vorp' 'TO_points' 'points_from_missed_shots' 'twos_generated'
#  'threes_generated' 'fg_per_mp' 'fga_per_mp' 'fg3_per_mp' 'fg3a_per_mp'
#  'fg2_per_mp' 'fg2a_per_mp' 'ft_per_mp' 'fta_per_mp' 'orb_per_mp'
#  'drb_per_mp' 'trb_per_mp' 'ast_per_mp' 'stl_per_mp' 'blk_per_mp'
#  'tov_per_mp' 'pf_per_mp' 'pts_per_mp' 'fg_per_poss' 'fga_per_poss'
#  'fg3_per_poss' 'fg3a_per_poss' 'fg2_per_poss' 'fg2a_per_poss'
#  'ft_per_poss' 'fta_per_poss' 'orb_per_poss' 'drb_per_poss' 'trb_per_poss'
#  'ast_per_poss' 'stl_per_poss' 'blk_per_poss' 'tov_per_poss' 'pf_per_poss'
#  'pts_per_poss' 'off_rtg' 'def_rtg' 'pos_simple']
#      ranker                 player pos  age team_id   g  gs  mp_per_g  \
# row
# 0         1           Steven Adams   C   26     OKC  29  29      27.8
# 1         2            Bam Adebayo   C   22     MIA  32  32      34.3
# 2         3      LaMarcus Aldridge   C   34     SAS  29  29      32.9
# 3         6          Jarrett Allen   C   21     BRK  31  28      26.5
# 4        11  Giannis Antetokounmpo  PF   25     MIL  31  31      31.1
# ..      ...                    ...  ..  ...     ...  ..  ..       ...
# 252     462        Marvin Williams  PF   33     CHO  30   0      20.8
# 253     468           Delon Wright  SG   27     DAL  30   2      20.5
# 254     469         Thaddeus Young  PF   31     CHI  32   0      21.8
# 255     470             Trae Young  PG   21     ATL  31  31      34.9
# 256     471            Cody Zeller   C   27     CHO  32  20      23.7
#
#      fg_per_g  fga_per_g  ...  trb_per_poss  ast_per_poss  stl_per_poss  \
# row                       ...
# 0         5.0        8.1  ...          17.0           4.8           1.1
# 1         5.8       10.3  ...          14.9           6.5           2.0
# 2         7.9       15.4  ...          10.8           3.5           0.9
# 3         4.7        7.2  ...          18.3           2.3           1.3
# 4        11.4       20.5  ...          19.1           8.4           1.9
# ..        ...        ...  ...           ...           ...           ...
# 252       2.6        5.5  ...           6.6           2.5           1.7
# 253       2.9        5.9  ...           8.4           7.8           3.6
# 254       3.5        8.8  ...           9.8           4.0           2.3
# 255       9.3       20.9  ...           5.7          11.0           1.6
# 256       4.6        8.4  ...          15.8           2.6           1.4
#
#      blk_per_poss  tov_per_poss  pf_per_poss  pts_per_poss  off_rtg  def_rtg  \
# row
# 0             2.2           2.7          3.3          20.4    123.0      105
# 1             1.8           3.9          3.7          22.1    117.0      102
# 2             2.7           2.1          3.3          28.1    116.0      110
# 3             2.5           2.1          4.3          21.5    133.0      103
# 4             1.8           5.4          4.6          45.1    117.0       96
# ..            ...           ...          ...           ...      ...      ...
# 252           1.1           1.7          4.4          18.0    119.0      113
# 253           0.7           1.7          2.7          18.5    130.0      105
# 254           0.5           3.4          4.1          19.2     94.0      105
# 255           0.1           6.3          2.0          38.0    110.0      116
# 256           0.9           3.1          5.3          24.4    116.0      111
#
#      pos_simple
# row
# 0             C
# 1             C
# 2             C
# 3             C
# 4             F
# ..          ...
# 252           F
# 253           G
# 254           F
# 255           G
# 256           C
#
# [257 rows x 98 columns]

# %%
df['pts_given_up'] = df['pts_per_g'] - df['TO_points'] - df['points_from_missed_shots']
df['pts_generated'] = df['twos_generated'] * 2 + df['threes_generated'] * 3
df['pts_diff'] = df['pts_per_g'] - df['pts_given_up'] + df['pts_generated']
df.sort_values('pts_given_up')[['player', 'pos', 'mp_per_g', 'TO_points', 'points_from_missed_shots', 'pts_given_up', 'pts_per_g', 'pts_diff']].head(40)
# Out:
#                 player pos  mp_per_g  TO_points  points_from_missed_shots  \
# row
# 114         Marc Gasol   C      28.2   1.444444                  4.777778
# 106  Terrance Ferguson  SF      26.9   0.961538                  3.074074
# 187    Frank Ntilikina  PG      22.5   1.709677                  2.843750
# 95      Jarrett Culver  SG      22.0   1.419355                  4.687500
# 212      3.148052        7.7  17.279221
# 113      3.236553       11.3  15.651682
# 254      3.254545        8.8   9.898396
# 104      3.352941        7.0  11.361345
# 13       3.368067        8.1   7.846218
# 28       3.400000        8.4  13.676471
# 184      3.546305       10.3  16.353695
# 17       3.724138        8.0  12.517241
# 220      3.776471       10.1  19.266387
# 191      3.781818        6.6   9.141711
# 172      3.890909        7.8   7.333333
# 232      3.928042        7.1   6.457672
# 23       3.982796        8.0  10.735954
# 149      3.987879       10.2  16.918004
# 24       4.020321        6.9   5.938503
# 123      4.113725        8.3   6.980392
# 180      4.147059        9.4  10.141830
# 162      4.241176        8.3   5.915966
# 252      4.250538        7.6   5.943212
# 228      4.266667        8.1   6.994624
# 154      4.297849        8.9   7.182796

# %%
labels = {'PG': 1, 'SG': 2, 'SF': 3, 'PF': 4, 'C': 5, 'G': 1.5, 'F': 3.5}

x = 'pts_diff'
y = 'pts_given_up'

l = [labels[i] for i in df['pos']]
colors=['purple', 'blue', 'teal', 'green', 'orange', 'pink', 'red', 'yellow']

plt.scatter(df[x], df[y], c=l, cmap='viridis', alpha=.3)
plt.colorbar().ax.set_ylabel('Position 1-5 (1-PG...5-C)', rotation=270, labelpad=20)

highlight = {'James Harden', 'Luka Dončić', 'Trae Young', 'Giannis Antetokounmpo', 'Andrew Wiggins',
            'LeBron James', 'Russell Westbrook', 'Paul George', 'Bradley Beal', 'Karl-Anthony Towns',
            'Anthony Davis', 'Montrezl Harrell', 'Marc Gasol', 'Draymond Green', 'Ben Simmons', 
             'Damian Lillard'}

for i, txt in enumerate(df['player']):
    if df['player'][i] in highlight:
        plt.annotate(txt[0] + '. ' + txt.split(' ')[-1], (df[x][i], df[y][i]))

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gcf().set_size_inches(15, 9)

plt.ylim(ymin=0)
plt.xlim(xmin=0)
# plt.gca().set_aspect('equal', adjustable='box')

# plt.legend()
plt.title('PPG v. Adjusted for points given up', fontsize=18)
plt.xlabel('Adjusted Offensive Contribution', fontsize=12)
plt.ylabel('Points Given Up', fontsize=12)
# Out:
# Text(0, 0.5, 'Points Given Up')

# %% [markdown]
# - James Harden is 2 points shy of a combined net offensive contribution from Giannis and KAT
# - Devin Booker and Andrew Wiggins at the same level as Kawhi and LeBron

# %%
labels = {'PG': 1, 'SG': 2, 'SF': 3, 'PF': 4, 'C': 5, 'G': 1.5, 'F': 3.5}

x = 'pts_diff'
y = 'points_from_missed_shots'

l = [labels[i] for i in df['pos']]
colors=['purple', 'blue', 'teal', 'green', 'orange', 'pink', 'red', 'yellow']

plt.scatter(df[x], df[y], c=l, cmap='viridis', alpha=.3)
plt.colorbar().ax.set_ylabel('Position 1-5 (1-PG...5-C)', rotation=270, labelpad=20)

highlight = {'James Harden', 'Luka Dončić', 'Trae Young', 'Giannis Antetokounmpo', 'Andrew Wiggins',
            'LeBron James', 'Russell Westbrook', 'Paul George', 'Bradley Beal', 'Karl-Anthony Towns',
            'Anthony Davis', 'Montrezl Harrell', 'Marc Gasol', 'Draymond Green'}

for i, txt in enumerate(df['player']):
    if df['player'][i] in highlight:
        plt.annotate(txt[0] + '. ' + txt.split(' ')[-1], (df[x][i], df[y][i]))

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gcf().set_size_inches(15, 9)

plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.gca().set_aspect('equal', adjustable='box')

plt.legend()
plt.title('PPG v. Adjusted for points given up', fontsize=18)
plt.ylabel('Opp. Points from Player Missed Shots', fontsize=12)
plt.xlabel('Adjusted Offensive Contribution', fontsize=12)
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 0, 'Adjusted Offensive Contribution')

# %%
labels = {'PG': 1, 'SG': 2, 'SF': 3, 'PF': 4, 'C': 5, 'G': 1.5, 'F': 3.5}

x = 'pts_diff'
y = 'TO_points'

l = [labels[i] for i in df['pos']]
colors=['purple', 'blue', 'teal', 'green', 'orange', 'pink', 'red', 'yellow']

plt.scatter(df[x], df[y], c=l, cmap='viridis', alpha=.3)
plt.colorbar().ax.set_ylabel('Position 1-5 (1-PG...5-C)', rotation=270, labelpad=20)

highlight = {'James Harden', 'Luka Dončić', 'Trae Young', 'Giannis Antetokounmpo', 'Andrew Wiggins',
            'LeBron James', 'Russell Westbrook', 'Paul George', 'Bradley Beal', 'Karl-Anthony Towns',
            'Damian Lillard'}

for i, txt in enumerate(df['player']):
    if df['player'][i] in highlight:
        plt.annotate(txt[0] + '. ' + txt.split(' ')[-1], (df[x][i], df[y][i]))

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gcf().set_size_inches(15, 9)

plt.ylim(ymin=0)
plt.xlim(xmin=0)
# plt.gca().set_aspect('equal', adjustable='box')

# plt.legend()
plt.title('PPG v. Adjusted for points given up', fontsize=18)
plt.ylabel('Opp. Points from Player Turnovers', fontsize=12)
plt.xlabel('Adjusted Offensive Contribution', fontsize=12)
# Out:
# Text(0.5, 0, 'Adjusted Offensive Contribution')

# %%
labels = {'PG': 1, 'SG': 2, 'SF': 3, 'PF': 4, 'C': 5, 'G': 1.5, 'F': 3.5}

x = 'pts_diff'
y = 'def_rtg'

l = [labels[i] for i in df['pos']]
colors=['purple', 'blue', 'teal', 'green', 'orange', 'pink', 'red', 'yellow']

plt.scatter(df[x], df[y], c=l, cmap='viridis', alpha=.3)
plt.colorbar().ax.set_ylabel('Position 1-5 (1-PG...5-C)', rotation=270, labelpad=20)

highlight = {'James Harden', 'Luka Dončić', 'Trae Young', 'Giannis Antetokounmpo', 'Andrew Wiggins',
            'LeBron James', 'Russell Westbrook', 'Paul George', 'Bradley Beal', 'Karl-Anthony Towns'}

for i, txt in enumerate(df['player']):
    if df['player'][i] in highlight:
        plt.annotate(txt[0] + '. ' + txt.split(' ')[-1], (df[x][i], df[y][i]))

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gcf().set_size_inches(15, 9)

# plt.ylim(ymin=0)
# plt.xlim(xmin=0)
# plt.gca().set_aspect('equal', adjustable='box')

# plt.legend()
plt.title('PPG v. Adjusted for points given up', fontsize=18)
plt.ylabel('Player Def. Rating', fontsize=12)
plt.xlabel('Adjusted Offensive Contribution', fontsize=12)
# Out:
# Text(0.5, 0, 'Adjusted Offensive Contribution')
